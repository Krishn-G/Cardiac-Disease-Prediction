# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('./input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
from sklearn.metrics import (
    accuracy_score, 
    precision_score, 
    recall_score, 
    f1_score, 
    confusion_matrix, 
    classification_report
)
# Out:
# ./input\heart.csv

# %%
# !pip install  matplotlib
# Out:
# Requirement already satisfied: matplotlib in e:\programs\anaconda3\envs\heart\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in e:\programs\anaconda3\envs\heart\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: six>=1.5 in e:\programs\anaconda3\envs\heart\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install yellowbrick
# Out:
# Requirement already satisfied: yellowbrick in e:\programs\anaconda3\envs\heart\lib\site-packages (1.5)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in e:\programs\anaconda3\envs\heart\lib\site-packages (from yellowbrick) (3.9.2)
# Requirement already satisfied: scipy>=1.0.0 in e:\programs\anaconda3\envs\heart\lib\site-packages (from yellowbrick) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in e:\programs\anaconda3\envs\heart\lib\site-packages (from yellowbrick) (1.5.2)
# Requirement already satisfied: numpy>=1.16.0 in e:\programs\anaconda3\envs\heart\lib\site-packages (from yellowbrick) (1.26.4)
# Requirement already satisfied: cycler>=0.10.0 in e:\programs\anaconda3\envs\heart\lib\site-packages (from yellowbrick) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (24.1)
# Requirement already satisfied: pillow>=8 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in e:\programs\anaconda3\envs\heart\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (6.4.5)
# Requirement already satisfied: joblib>=1.2.0 in e:\programs\anaconda3\envs\heart\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\programs\anaconda3\envs\heart\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (3.5.0)
# Requirement already satisfied: zipp>=3.1.0 in e:\programs\anaconda3\envs\heart\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.20.2)
# Requirement already satisfied: six>=1.5 in e:\programs\anaconda3\envs\heart\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in e:\programs\anaconda3\envs\heart\lib\site-packages (0.14.4)
# Requirement already satisfied: numpy<3,>=1.22.3 in e:\programs\anaconda3\envs\heart\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in e:\programs\anaconda3\envs\heart\lib\site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in e:\programs\anaconda3\envs\heart\lib\site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: patsy>=0.5.6 in e:\programs\anaconda3\envs\heart\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in e:\programs\anaconda3\envs\heart\lib\site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\programs\anaconda3\envs\heart\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\programs\anaconda3\envs\heart\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\programs\anaconda3\envs\heart\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: six>=1.5 in e:\programs\anaconda3\envs\heart\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.16.0)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in e:\programs\anaconda3\envs\heart\lib\site-packages (2.1.2)
# Requirement already satisfied: numpy in e:\programs\anaconda3\envs\heart\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in e:\programs\anaconda3\envs\heart\lib\site-packages (from xgboost) (1.13.1)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
import yellowbrick
import pickle

from matplotlib.collections import PathCollection
from statsmodels.graphics.gofplots import qqplot
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler, Normalizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.metrics import classification_report, accuracy_score

from xgboost import XGBClassifier
from yellowbrick.classifier import PrecisionRecallCurve, ROCAUC, ConfusionMatrix
from yellowbrick.style import set_palette
from yellowbrick.model_selection import LearningCurve, FeatureImportances
from yellowbrick.contrib.wrapper import wrap

# --- Libraries Settings ---
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
plt.rcParams['figure.dpi']=100
set_palette('dark')

# %% [markdown]
# # --- Create List of Color Palletes ---

# %%
red_grad = ['#0081AF', '#00ABE7', '#2DC7FF', '#EAD2AC', '#EABA6B']
pink_grad = ['#8D5A97', '#907F9F', '#A4A5AE', '#B0C7BD', '#B8EBD0']
purple_grad = ['#B3C2F2', '#735CDD', '#9000B3', '#7E007B', '#37000A']
color_mix = ['#373F51', '#008DD5', '#DFBBB1', '#F56476', '#E43F6F']
black_grad = ['#393D3F', '#FDFDFF', '#C6C5B9', '#62929E', '#546A7B']

# %% [markdown]
# # --- Plot Color Palletes --

# %%
sns.palplot(red_grad)
sns.palplot(pink_grad)
sns.palplot(purple_grad)
sns.palplot(color_mix)
sns.palplot(black_grad)

# %% [markdown]
# # --- Importing Dataset ---

# %%
df = pd.read_csv("./input/heart.csv")

# --- Reading Dataset ---
df.head().style.background_gradient(cmap='Reds').set_properties(**{'font-family': 'Segoe UI'})
# Out:
# <style type="text/css">
# #T_cb021_row0_col0, #T_cb021_row0_col2, #T_cb021_row0_col3, #T_cb021_row0_col5, #T_cb021_row0_col8, #T_cb021_row0_col13, #T_cb021_row1_col2, #T_cb021_row1_col6, #T_cb021_row1_col10, #T_cb021_row1_col11, #T_cb021_row1_col13, #T_cb021_row2_col2, #T_cb021_row2_col4, #T_cb021_row2_col5, #T_cb021_row2_col10, #T_cb021_row2_col11, #T_cb021_row2_col13, #T_cb021_row3_col2, #T_cb021_row3_col5, #T_cb021_row3_col8, #T_cb021_row3_col9, #T_cb021_row3_col13, #T_cb021_row4_col1, #T_cb021_row4_col2, #T_cb021_row4_col7, #T_cb021_row4_col8, #T_cb021_row4_col12, #T_cb021_row4_col13 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cb021_row0_col1, #T_cb021_row0_col6, #T_cb021_row0_col7, #T_cb021_row0_col10, #T_cb021_row0_col12, #T_cb021_row1_col1, #T_cb021_row1_col5, #T_cb021_row1_col8, #T_cb021_row1_col9, #T_cb021_row1_col12, #T_cb021_row2_col0, #T_cb021_row2_col1, #T_cb021_row2_col6, #T_cb021_row2_col8, #T_cb021_row2_col12, #T_cb021_row3_col1, #T_cb021_row3_col3, #T_cb021_row3_col6, #T_cb021_row3_col10, #T_cb021_row3_col12, #T_cb021_row4_col4, #T_cb021_row4_col5, #T_cb021_row4_col6, #T_cb021_row4_col11 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cb021_row0_col4 {
#   background-color: #fca588;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cb021_row0_col9 {
#   background-color: #fca486;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cb021_row0_col11 {
#   background-color: #e32f27;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cb021_row1_col0 {
#   background-color: #ffece3;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cb021_row1_col3 {
#   background-color: #e83429;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cb021_row1_col4, #T_cb021_row3_col4 {
#   background-color: #fcbea5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cb021_row1_col7 {
#   background-color: #be151a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cb021_row2_col3 {
#   background-color: #a60f15;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cb021_row2_col7 {
#   background-color: #fca98c;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cb021_row2_col9 {
#   background-color: #b01217;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cb021_row3_col0, #T_cb021_row4_col10 {
#   background-color: #fb694a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cb021_row3_col7 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cb021_row3_col11 {
#   background-color: #fca082;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_cb021_row4_col0 {
#   background-color: #f6553c;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cb021_row4_col3 {
#   background-color: #f5523a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_cb021_row4_col9 {
#   background-color: #f0402f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_cb021">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb021_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_cb021_level0_col1" class="col_heading level0 col1" >sex</th>
#       <th id="T_cb021_level0_col2" class="col_heading level0 col2" >cp</th>
#       <th id="T_cb021_level0_col3" class="col_heading level0 col3" >trestbps</th>
#       <th id="T_cb021_level0_col4" class="col_heading level0 col4" >chol</th>
#       <th id="T_cb021_level0_col5" class="col_heading level0 col5" >fbs</th>
#       <th id="T_cb021_level0_col6" class="col_heading level0 col6" >restecg</th>
#       <th id="T_cb021_level0_col7" class="col_heading level0 col7" >thalach</th>
#       <th id="T_cb021_level0_col8" class="col_heading level0 col8" >exang</th>
#       <th id="T_cb021_level0_col9" class="col_heading level0 col9" >oldpeak</th>
#       <th id="T_cb021_level0_col10" class="col_heading level0 col10" >slope</th>
#       <th id="T_cb021_level0_col11" class="col_heading level0 col11" >ca</th>
#       <th id="T_cb021_level0_col12" class="col_heading level0 col12" >thal</th>
#       <th id="T_cb021_level0_col13" class="col_heading level0 col13" >target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb021_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb021_row0_col0" class="data row0 col0" >52</td>
#       <td id="T_cb021_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_cb021_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_cb021_row0_col3" class="data row0 col3" >125</td>
#       <td id="T_cb021_row0_col4" class="data row0 col4" >212</td>
#       <td id="T_cb021_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_cb021_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_cb021_row0_col7" class="data row0 col7" >168</td>
#       <td id="T_cb021_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_cb021_row0_col9" class="data row0 col9" >1.000000</td>
#       <td id="T_cb021_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_cb021_row0_col11" class="data row0 col11" >2</td>
#       <td id="T_cb021_row0_col12" class="data row0 col12" >3</td>
#       <td id="T_cb021_row0_col13" class="data row0 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_cb021_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb021_row1_col0" class="data row1 col0" >53</td>
#       <td id="T_cb021_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_cb021_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_cb021_row1_col3" class="data row1 col3" >140</td>
#       <td id="T_cb021_row1_col4" class="data row1 col4" >203</td>
#       <td id="T_cb021_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_cb021_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_cb021_row1_col7" class="data row1 col7" >155</td>
#       <td id="T_cb021_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_cb021_row1_col9" class="data row1 col9" >3.100000</td>
#       <td id="T_cb021_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_cb021_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_cb021_row1_col12" class="data row1 col12" >3</td>
#       <td id="T_cb021_row1_col13" class="data row1 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_cb021_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cb021_row2_col0" class="data row2 col0" >70</td>
#       <td id="T_cb021_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_cb021_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_cb021_row2_col3" class="data row2 col3" >145</td>
#       <td id="T_cb021_row2_col4" class="data row2 col4" >174</td>
#       <td id="T_cb021_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_cb021_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_cb021_row2_col7" class="data row2 col7" >125</td>
#       <td id="T_cb021_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_cb021_row2_col9" class="data row2 col9" >2.600000</td>
#       <td id="T_cb021_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_cb021_row2_col11" class="data row2 col11" >0</td>
#       <td id="T_cb021_row2_col12" class="data row2 col12" >3</td>
#       <td id="T_cb021_row2_col13" class="data row2 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_cb021_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cb021_row3_col0" class="data row3 col0" >61</td>
#       <td id="T_cb021_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_cb021_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_cb021_row3_col3" class="data row3 col3" >148</td>
#       <td id="T_cb021_row3_col4" class="data row3 col4" >203</td>
#       <td id="T_cb021_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_cb021_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_cb021_row3_col7" class="data row3 col7" >161</td>
#       <td id="T_cb021_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_cb021_row3_col9" class="data row3 col9" >0.000000</td>
#       <td id="T_cb021_row3_col10" class="data row3 col10" >2</td>
#       <td id="T_cb021_row3_col11" class="data row3 col11" >1</td>
#       <td id="T_cb021_row3_col12" class="data row3 col12" >3</td>

# %% [markdown]
# # --- Print Dataset Info ---

# %%
print('\033[1m'+'.: Dataset Info :.'+'\033[0m')
print('*' * 30)
print('Total Rows:'+'\033[1m', df.shape[0])
print('\033[0m'+'Total Columns:'+'\033[1m', df.shape[1])
print('\033[0m'+'*' * 30)
print('\n')

# --- Print Dataset Detail ---
print('\033[1m'+'.: Dataset Details :.'+'\033[0m')
print('*' * 30)
df.info(memory_usage = False)
# Out:
# .: Dataset Info :.
# ******************************
# Total Rows: 1025
# Total Columns: 14
# ******************************
#
#
# .: Dataset Details :.
# ******************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)

# %% [markdown]
# # --- Fix Data Types ---

# %%
lst=['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']
df[lst] = df[lst].astype(object)

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### sex (Gender)

# %%
# --- Setting Colors, Labels, Order ---
colors=color_mix[2:4]
labels=['Female', 'Male']
order=df['sex'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16, 8))
plt.suptitle('Sex (Gender) Distribution', fontweight='heavy', 
             fontsize='16', fontfamily='sans-serif', color=black_grad[0])

# --- Pie Chart ---
plt.subplot(1, 2, 1)
plt.title('Pie Chart', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
plt.pie(df['sex'].value_counts(), labels=labels, colors=colors, pctdistance=0.7,
        autopct='%.2f%%', wedgeprops=dict(alpha=0.8, edgecolor=black_grad[1]),
        textprops={'fontsize':12})
centre=plt.Circle((0, 0), 0.45, fc='white', edgecolor=black_grad[1])
plt.gcf().gca().add_artist(centre)

# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, 
          fontfamily='sans-serif', color=black_grad[0])
ax = sns.countplot(x='sex', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10, 
             bbox=dict(facecolor='none', edgecolor=black_grad[0], 
                       linewidth=0.25, boxstyle='round'))

plt.xlabel('Gender', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.xticks([0, 1], labels)
plt.grid(axis='y', alpha=0.4)
countplt
# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 25)
print('\033[1m'+'.: Sex (Gender) Total :.'+'\033[0m')
print('*' * 25)
df.sex.value_counts(dropna=False)
# Out:
# *************************
# .: Sex (Gender) Total :.
# *************************
# sex
# 1    713
# 0    312
# Name: count, dtype: int64

# %% [markdown]
# ### cp (Chest Pain Type)

# %%
# --- Setting Colors, Labels, Order ---
colors=pink_grad[0:4]
labels=['Type 0', 'Type 2', 'Type 1', 'Type 3']
order=df['cp'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16, 8))
plt.suptitle('Chest Pain Type Distribution', fontweight='heavy', fontsize=16, 
             fontfamily='sans-serif', color=black_grad[0])

# --- Pie Chart ---
plt.subplot(1, 2, 1)
plt.title('Pie Chart', fontweight='bold', fontsize=14,fontfamily='sans-serif', 
          color=black_grad[0])
plt.pie(df['cp'].value_counts(), labels=labels, colors=colors, pctdistance=0.7, 
        autopct='%.2f%%', textprops={'fontsize':12},
        wedgeprops=dict(alpha=0.8, edgecolor=black_grad[1]))
centre=plt.Circle((0, 0), 0.45, fc='white', edgecolor=black_grad[1])
plt.gcf().gca().add_artist(centre)

# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
ax = sns.countplot(x='cp', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10,
             bbox=dict(facecolor='none', edgecolor=black_grad[0], linewidth=0.25,
                       boxstyle='round'))

plt.xlabel('Pain Type', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.xticks([0, 1, 2, 3], labels)
plt.grid(axis='y', alpha=0.4)
countplt

# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 30)
print('\033[1m'+'.: Chest Pain Type Total :.'+'\033[0m')
print('*' * 30)
df.cp.value_counts(dropna=False)
# Out:
# ******************************
# .: Chest Pain Type Total :.
# ******************************
# cp
# 0    497
# 2    284
# 1    167
# 3     77
# Name: count, dtype: int64

# %% [markdown]
# ### fbs (Fasting Blood Sugar)

# %%
# --- Setting Colors, Labels, Order ---
colors=color_mix[0:2]
labels=['< 120 mg/dl', '> 120 mg/dl']
order=df['fbs'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16, 8))
plt.suptitle('Fasting Blood Sugar Distribution', fontweight='heavy', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])

# --- Pie Chart ---
plt.subplot(1, 2, 1)
plt.title('Pie Chart', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
plt.pie(df['fbs'].value_counts(), labels=labels, colors=colors,
        wedgeprops=dict(alpha=0.8, edgecolor=black_grad[1]), autopct='%.2f%%',
        pctdistance=0.7, textprops={'fontsize':12})
centre=plt.Circle((0, 0), 0.45, fc='white', edgecolor=black_grad[1])
plt.gcf().gca().add_artist(centre)

# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
ax = sns.countplot(x='fbs', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10,
             bbox=dict(facecolor='none', edgecolor=black_grad[0], linewidth=0.25,
                       boxstyle='round'))

plt.xlabel('Fasting Blood Sugar', fontweight='bold', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.xticks([0, 1], labels)
plt.grid(axis='y', alpha=0.4)
countplt


# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 32)
print('\033[1m'+'.: Fasting Blood Sugar Total :.'+'\033[0m')
print('*' * 32)
df.fbs.value_counts(dropna=False)
# Out:
# ********************************
# .: Fasting Blood Sugar Total :.
# ********************************
# fbs
# 0    872
# 1    153
# Name: count, dtype: int64

# %% [markdown]
# ### restecg (Resting Electrocardiographic Results)

# %%
# --- Setting Colors, Labels, Order ---
colors=pink_grad[1:4]
labels=['1', '0', '2']
order=df['restecg'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16, 8))
plt.suptitle('Resting Electrocardiographic Distribution', fontweight='heavy', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])

# --- Pie Chart ---
plt.subplot(1,2,1)
plt.title('Pie Chart', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
plt.pie(df['restecg'].value_counts(), labels=labels, colors=colors, 
        wedgeprops=dict(alpha=0.8, edgecolor=black_grad[1]), autopct='%.2f%%',
        pctdistance=0.7, textprops={'fontsize':12})
centre=plt.Circle((0, 0), 0.45, fc='white', edgecolor=black_grad[1])
plt.gcf().gca().add_artist(centre)

# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
ax = sns.countplot(x='restecg', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10,
             bbox=dict(facecolor='none', edgecolor=black_grad[0], linewidth=0.25,
                       boxstyle='round'))

plt.xlabel('Resting Electrocardiographic', fontweight='bold', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.grid(axis='y', alpha=0.4)
countplt

# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 50)
print('\033[1m'+'.: Resting Electrocardiographic Results Total :.'+'\033[0m')
print('*' * 50)
df.restecg.value_counts(dropna=False)
# Out:
# **************************************************
# .: Resting Electrocardiographic Results Total :.
# **************************************************
# restecg
# 1    513
# 0    497
# 2     15
# Name: count, dtype: int64

# %% [markdown]
# ### exang (Exercise Induced Angina)

# %%
# --- Setting Colors, Labels, Order ---
colors=red_grad[1:3]
labels=['False', 'True']
order=df['exang'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16, 8))
plt.suptitle('Exercise Induced Angina Distribution', fontweight='heavy', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])

# --- Pie Chart ---
plt.subplot(1,2,1)
plt.title('Pie Chart', fontweight='bold', fontsize=14, fontfamily='sans-serif',
          color=black_grad[0])
plt.pie(df['exang'].value_counts(), labels=labels, colors=colors, 
        wedgeprops=dict(alpha=0.8, edgecolor=black_grad[1]), autopct='%.2f%%',
        pctdistance=0.7, textprops={'fontsize':12})
centre=plt.Circle((0, 0), 0.45, fc='white', edgecolor=black_grad[1])
plt.gcf().gca().add_artist(centre)

# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
ax = sns.countplot(x='exang', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10,
             bbox=dict(facecolor='none', edgecolor=black_grad[0], linewidth=0.25,
                       boxstyle='round'))

plt.xlabel('Exercise Induced Angina', fontweight='bold', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.xticks([0, 1], labels)
plt.grid(axis='y', alpha=0.4)
countplt

# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 35)
print('\033[1m'+'.: Exercise Induced Angina Total :.'+'\033[0m')
print('*' * 35)
df.exang.value_counts(dropna=False)
# Out:
# ***********************************
# .: Exercise Induced Angina Total :.
# ***********************************
# exang
# 0    680
# 1    345
# Name: count, dtype: int64

# %% [markdown]
# ### slope (Slope of the Peak Exercise)

# %%
# --- Setting Colors, Labels, Order ---
colors=purple_grad[2:5]
labels=['2', '1', '0']
order=df['slope'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16, 8))
plt.suptitle('Slope of the Peak Exercise Distribution', fontweight='heavy', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])

# --- Pie Chart ---
plt.subplot(1, 2, 1)
plt.title('Pie Chart', fontweight='bold', fontsize=14,
          fontfamily='sans-serif', color=black_grad[0])
plt.pie(df['slope'].value_counts(), labels=labels, colors=colors, 
        wedgeprops=dict(alpha=0.8, edgecolor=black_grad[1]), autopct='%.2f%%',
        pctdistance=0.7, textprops={'fontsize':12})
centre=plt.Circle((0, 0), 0.45, fc='white', edgecolor=black_grad[1])
plt.gcf().gca().add_artist(centre)


# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
ax = sns.countplot(x='slope', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10,
             bbox=dict(facecolor='none', edgecolor=black_grad[0], linewidth=0.25,
                       boxstyle='round'))

plt.xlabel('Slope', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.grid(axis='y', alpha=0.4)
countplt
# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 20)
print('\033[1m'+'.: Slope Total :.'+'\033[0m')
print('*' * 20)
df.slope.value_counts(dropna=False)
# Out:
# ********************
# .: Slope Total :.
# ********************
# slope
# 1    482
# 2    469
# 0     74
# Name: count, dtype: int64

# %% [markdown]
# ### ca (Number of Major Vessels)

# %%
# --- Setting Colors, Labels, Order ---
colors=purple_grad
labels=['0', '1', '2', '3', '4']
order=df['ca'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16, 8))
plt.suptitle('Number of Major Vessels Distribution', fontweight='heavy', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])

# --- Pie Chart ---
plt.subplot(1,2,1)
plt.title('Pie Chart', fontweight='bold', fontsize=14, fontfamily='sans-serif',
          color=black_grad[0])
plt.pie(df['ca'].value_counts(), labels=labels, colors=colors, 
        wedgeprops=dict(alpha=0.8, edgecolor=black_grad[1]), 
        autopct='%.2f%%', pctdistance=0.7, textprops={'fontsize':12})

centre=plt.Circle((0, 0), 0.45, fc='white', edgecolor=black_grad[1])
plt.gcf().gca().add_artist(centre)

# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
ax = sns.countplot(x='ca', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10,
             bbox=dict(facecolor='none', edgecolor=black_grad[0], linewidth=0.25,
                       boxstyle='round'))

plt.xlabel('Number of Major Vessels', fontweight='bold', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.grid(axis='y', alpha=0.4)
countplt

# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 40)
print('\033[1m'+'.: Number of Major Vessels Total :.'+'\033[0m')
print('*' * 40)
df.ca.value_counts(dropna=False)
# Out:
# ****************************************
# .: Number of Major Vessels Total :.
# ****************************************
# ca
# 0    578
# 1    226
# 2    134
# 3     69
# 4     18
# Name: count, dtype: int64

# %% [markdown]
# ### thal

# %%
# --- Setting Colors, Labels, Order ---
colors=red_grad[0:4]
labels=['2', '3', '1', '0']
order=df['thal'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16,8))
plt.suptitle('"thal" Distribution', fontweight='heavy', fontsize=16, 
             fontfamily='sans-serif', color=black_grad[0])

# --- Pie Chart ---
plt.subplot(1,2,1)
plt.title('Pie Chart', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
plt.pie(df['thal'].value_counts(), labels=labels, colors=colors, 
        wedgeprops=dict(alpha=0.8, edgecolor=black_grad[1]), 
        autopct='%.2f%%', pctdistance=0.7, textprops={'fontsize':12})

centre=plt.Circle((0, 0), 0.45, fc='white', edgecolor=black_grad[1])
plt.gcf().gca().add_artist(centre)

# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
ax = sns.countplot(x='thal', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10,
             bbox=dict(facecolor='none', edgecolor=black_grad[0], linewidth=0.25,
                       boxstyle='round'))

plt.xlabel('Number of "thal"', fontweight='bold', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.grid(axis='y', alpha=0.4)
countplt

# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 20)
print('\033[1m'+'.: "thal" Total :.'+'\033[0m')
print('*' * 20)
df.thal.value_counts(dropna=False)
# Out:
# ********************
# .: "thal" Total :.
# ********************
# thal
# 2    544
# 3    410
# 1     64
# 0      7
# Name: count, dtype: int64

# %% [markdown]
# ### target (Heart Diseases Status)

# %%
# --- Setting Colors, Labels, Order ---
colors=color_mix[3:5]
labels=['True', 'False']
order=df['target'].value_counts().index

# --- Size for Both Figures ---
plt.figure(figsize=(16,8))
plt.suptitle('Heart Diseases Distribution', fontweight='heavy', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])

# --- Pie Chart ---
plt.subplot(1, 2, 1)
plt.title('Pie Chart', fontweight='bold', fontsize=14, fontfamily='sans-serif',
          color=black_grad[0])
plt.pie(df['target'].value_counts(), labels=labels, colors=colors, 
        wedgeprops=dict(alpha=0.8, edgecolor=black_grad[1]), autopct='%.2f%%',
        pctdistance=0.7, textprops={'fontsize':12})
centre=plt.Circle((0, 0), 0.45, fc='white', edgecolor=black_grad[1])
plt.gcf().gca().add_artist(centre)

# --- Histogram ---
countplt = plt.subplot(1, 2, 2)
plt.title('Histogram', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[0])
ax = sns.countplot(x='target', data=df, palette=colors, order=order,
                   edgecolor=black_grad[2], alpha=0.85)
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+4.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10,
             bbox=dict(facecolor='none', edgecolor=black_grad[0], linewidth=0.25,
                       boxstyle='round'))

plt.xlabel('Heart Disease Status', fontweight='bold', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Total', fontweight='bold', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])
plt.xticks([0, 1], labels)
plt.grid(axis='y', alpha=0.4)
countplt

# --- Count Categorical Labels w/out Dropping Null Walues ---
print('*' * 45)
print('\033[1m'+'.: Heart Diseases Status (target) Total :.'+'\033[0m')
print('*' * 45)
df.target.value_counts(dropna=False)
# Out:
# *********************************************
# .: Heart Diseases Status (target) Total :.
# *********************************************
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %% [markdown]
# ## Numerical Variable

# %% [markdown]
# ### Descriptive Statistics

# %%
# --- Descriptive Statistics ---
df.select_dtypes(exclude='object').describe().T.style.background_gradient(cmap='PuRd').set_properties(**{'font-family': 'Segoe UI'})
# Out:
# <style type="text/css">
# #T_a467f_row0_col0, #T_a467f_row1_col0, #T_a467f_row2_col0, #T_a467f_row3_col0, #T_a467f_row4_col0, #T_a467f_row4_col1, #T_a467f_row4_col3, #T_a467f_row4_col4, #T_a467f_row4_col5, #T_a467f_row4_col6, #T_a467f_row5_col0, #T_a467f_row5_col1, #T_a467f_row5_col2, #T_a467f_row5_col3, #T_a467f_row5_col4, #T_a467f_row5_col5, #T_a467f_row5_col6, #T_a467f_row5_col7 {
#   background-color: #f7f4f9;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_a467f_row0_col1, #T_a467f_row0_col6 {
#   background-color: #d9c3df;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_a467f_row0_col2 {
#   background-color: #e1d4e8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_a467f_row0_col3, #T_a467f_row0_col4 {
#   background-color: #d7c0de;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_a467f_row0_col5 {
#   background-color: #d7bfdd;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_a467f_row0_col7 {
#   background-color: #e6deee;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_a467f_row1_col1 {
#   background-color: #e155a6;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_a467f_row1_col2 {
#   background-color: #cda0cd;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_a467f_row1_col3 {
#   background-color: #cf1358;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_a467f_row1_col4 {
#   background-color: #e3449b;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_a467f_row1_col5 {
#   background-color: #e251a3;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_a467f_row1_col6 {
#   background-color: #df62ae;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_a467f_row1_col7 {
#   background-color: #cb9bca;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_a467f_row2_col1, #T_a467f_row2_col2, #T_a467f_row2_col3, #T_a467f_row2_col4, #T_a467f_row2_col5, #T_a467f_row2_col6, #T_a467f_row2_col7 {
#   background-color: #67001f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_a467f_row3_col1, #T_a467f_row3_col6 {
#   background-color: #e63390;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_a467f_row3_col2 {
#   background-color: #d47cbb;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_a467f_row3_col3 {
#   background-color: #e3469c;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_a467f_row3_col4 {
#   background-color: #e72989;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_a467f_row3_col5 {
#   background-color: #e62887;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_a467f_row3_col7 {
#   background-color: #cb99ca;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_a467f_row4_col2 {
#   background-color: #f5f2f8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_a467f_row4_col7 {
#   background-color: #f6f3f8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_a467f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a467f_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_a467f_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_a467f_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_a467f_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_a467f_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_a467f_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_a467f_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_a467f_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a467f_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_a467f_row0_col0" class="data row0 col0" >1025.000000</td>
#       <td id="T_a467f_row0_col1" class="data row0 col1" >54.434146</td>
#       <td id="T_a467f_row0_col2" class="data row0 col2" >9.072290</td>
#       <td id="T_a467f_row0_col3" class="data row0 col3" >29.000000</td>
#       <td id="T_a467f_row0_col4" class="data row0 col4" >48.000000</td>
#       <td id="T_a467f_row0_col5" class="data row0 col5" >56.000000</td>
#       <td id="T_a467f_row0_col6" class="data row0 col6" >61.000000</td>
#       <td id="T_a467f_row0_col7" class="data row0 col7" >77.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a467f_level0_row1" class="row_heading level0 row1" >trestbps</th>
#       <td id="T_a467f_row1_col0" class="data row1 col0" >1025.000000</td>
#       <td id="T_a467f_row1_col1" class="data row1 col1" >131.611707</td>
#       <td id="T_a467f_row1_col2" class="data row1 col2" >17.516718</td>
#       <td id="T_a467f_row1_col3" class="data row1 col3" >94.000000</td>
#       <td id="T_a467f_row1_col4" class="data row1 col4" >120.000000</td>
#       <td id="T_a467f_row1_col5" class="data row1 col5" >130.000000</td>
#       <td id="T_a467f_row1_col6" class="data row1 col6" >140.000000</td>
#       <td id="T_a467f_row1_col7" class="data row1 col7" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a467f_level0_row2" class="row_heading level0 row2" >chol</th>
#       <td id="T_a467f_row2_col0" class="data row2 col0" >1025.000000</td>
#       <td id="T_a467f_row2_col1" class="data row2 col1" >246.000000</td>
#       <td id="T_a467f_row2_col2" class="data row2 col2" >51.592510</td>
#       <td id="T_a467f_row2_col3" class="data row2 col3" >126.000000</td>
#       <td id="T_a467f_row2_col4" class="data row2 col4" >211.000000</td>
#       <td id="T_a467f_row2_col5" class="data row2 col5" >240.000000</td>
#       <td id="T_a467f_row2_col6" class="data row2 col6" >275.000000</td>
#       <td id="T_a467f_row2_col7" class="data row2 col7" >564.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a467f_level0_row3" class="row_heading level0 row3" >thalach</th>
#       <td id="T_a467f_row3_col0" class="data row3 col0" >1025.000000</td>
#       <td id="T_a467f_row3_col1" class="data row3 col1" >149.114146</td>
#       <td id="T_a467f_row3_col2" class="data row3 col2" >23.005724</td>
#       <td id="T_a467f_row3_col3" class="data row3 col3" >71.000000</td>
#       <td id="T_a467f_row3_col4" class="data row3 col4" >132.000000</td>
#       <td id="T_a467f_row3_col5" class="data row3 col5" >152.000000</td>
#       <td id="T_a467f_row3_col6" class="data row3 col6" >166.000000</td>
#       <td id="T_a467f_row3_col7" class="data row3 col7" >202.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a467f_level0_row4" class="row_heading level0 row4" >oldpeak</th>
#       <td id="T_a467f_row4_col0" class="data row4 col0" >1025.000000</td>
#       <td id="T_a467f_row4_col1" class="data row4 col1" >1.071512</td>
#       <td id="T_a467f_row4_col2" class="data row4 col2" >1.175053</td>
#       <td id="T_a467f_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_a467f_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_a467f_row4_col5" class="data row4 col5" >0.800000</td>
#       <td id="T_a467f_row4_col6" class="data row4 col6" >1.800000</td>
#       <td id="T_a467f_row4_col7" class="data row4 col7" >6.200000</td>
#     </tr>
#     <tr>
#       <th id="T_a467f_level0_row5" class="row_heading level0 row5" >target</th>
#       <td id="T_a467f_row5_col0" class="data row5 col0" >1025.000000</td>
#       <td id="T_a467f_row5_col1" class="data row5 col1" >0.513171</td>
#       <td id="T_a467f_row5_col2" class="data row5 col2" >0.500070</td>
#       <td id="T_a467f_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_a467f_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_a467f_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_a467f_row5_col6" class="data row5 col6" >1.000000</td>
#       <td id="T_a467f_row5_col7" class="data row5 col7" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Continuous Column Distribution

# %%
# --- Variable, Color & Plot Size ---
var = 'age'
color = color_mix[0]
fig=plt.figure(figsize=(12, 12))

# --- Skewness & Kurtosis ---
print('\033[1m'+'.: Age Column Skewness & Kurtosis :.'+'\033[0m')
print('*' * 40)
print('Skewness:'+'\033[1m {:.3f}'.format(df[var].skew(axis = 0, skipna = True)))
print('\033[0m'+'Kurtosis:'+'\033[1m {:.3f}'.format(df[var].kurt(axis = 0, skipna = True)))
print('\n')

# --- General Title ---
fig.suptitle('Age Column Distribution', fontweight='bold', fontsize=16, 
             fontfamily='sans-serif', color=black_grad[0])
fig.subplots_adjust(top=0.9)

# --- Histogram ---
ax_1=fig.add_subplot(2, 2, 2)
plt.title('Histogram Plot', fontweight='bold', fontsize=14, 
          fontfamily='sans-serif', color=black_grad[1])
sns.histplot(data=df, x=var, kde=True, color=color)
plt.xlabel('Total', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Age', fontweight='regular', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])

# --- Q-Q Plot ---
ax_2=fig.add_subplot(2, 2, 4)
plt.title('Q-Q Plot', fontweight='bold', fontsize=14, 
          fontfamily='sans-serif', color=black_grad[1])
qqplot(df[var], fit=True, line='45', ax=ax_2, markerfacecolor=color, 
       markeredgecolor=color, alpha=0.6)
plt.xlabel('Theoritical Quantiles', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Sample Quantiles', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])

# --- Box Plot ---
ax_3=fig.add_subplot(1, 2, 1)
plt.title('Box Plot', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[1])
sns.boxplot(data=df, y=var, color=color, boxprops=dict(alpha=0.8), linewidth=1.5)
plt.ylabel('Age', fontweight='regular', fontsize=11, fontfamily='sans-serif', 
           color=black_grad[1])

plt.show()
# Out:
# .: Age Column Skewness & Kurtosis :.
# ****************************************
# Skewness: -0.249
# Kurtosis: -0.526

# %% [markdown]
# #### trestbps (Resting Blood Pressure in mm Hg)

# %%
# --- Variable, Color & Plot Size ---
var = 'trestbps'
color = color_mix[2]
fig=plt.figure(figsize=(12, 12))

# --- Skewness & Kurtosis ---
print('\033[1m'+'.: Resting Blood Pressure Column Skewness & Kurtosis :.'+'\033[0m')
print('*' * 55)
print('Skewness:'+'\033[1m {:.3f}'.format(df[var].skew(axis = 0, skipna = True)))
print('\033[0m'+'Kurtosis:'+'\033[1m {:.3f}'.format(df[var].kurt(axis = 0, skipna = True)))
print('\n')

# --- General Title ---
fig.suptitle('Resting Blood Pressure Column Distribution', fontweight='bold', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])
fig.subplots_adjust(top=0.9)

# --- Histogram ---
ax_1=fig.add_subplot(2, 2, 2)
plt.title('Histogram Plot', fontweight='bold', fontsize=14, 
          fontfamily='sans-serif', color=black_grad[1])
sns.histplot(data=df, x=var, kde=True, color=color)
plt.xlabel('Total', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Resting Blood Pressure', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])

# --- Q-Q Plot ---
ax_2=fig.add_subplot(2, 2, 4)
plt.title('Q-Q Plot', fontweight='bold', fontsize=14, 
          fontfamily='sans-serif', color=black_grad[1])
qqplot(df[var], fit=True, line='45', ax=ax_2, markerfacecolor=color, 
       markeredgecolor=color, alpha=0.6)
plt.xlabel('Theoritical Quantiles', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Sample Quantiles', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])

# --- Box Plot ---
ax_3=fig.add_subplot(1, 2, 1)
plt.title('Box Plot', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[1])
sns.boxplot(data=df, y=var, color=color, boxprops=dict(alpha=0.8), linewidth=1.5)
plt.ylabel('Resting Blood Pressure', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])

plt.show()
# Out:
# .: Resting Blood Pressure Column Skewness & Kurtosis :.
# *******************************************************
# Skewness: 0.740
# Kurtosis: 0.991

# %% [markdown]
# #### chol (Serum Cholestoral in mg/dl)

# %%
# --- Variable, Color & Plot Size ---
var = 'chol'
color = color_mix[4]
fig=plt.figure(figsize=(12, 12))

# --- Skewness & Kurtosis ---
print('\033[1m'+'.: Serum Cholestoral Column Skewness & Kurtosis :.'+'\033[0m')
print('*' * 45)
print('Skewness:'+'\033[1m {:.3f}'.format(df[var].skew(axis = 0, skipna = True)))
print('\033[0m'+'Kurtosis:'+'\033[1m {:.3f}'.format(df[var].kurt(axis = 0, skipna = True)))
print('\n')

# --- General Title ---
fig.suptitle('Serum Cholestoral Column Distribution', fontweight='bold', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])
fig.subplots_adjust(top=0.9)

# --- Histogram ---
ax_1=fig.add_subplot(2, 2, 2)
plt.title('Histogram Plot', fontweight='bold', fontsize=14, 
          fontfamily='sans-serif', color=black_grad[1])
sns.histplot(data=df, x=var, kde=True, color=color)
plt.xlabel('Total', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Serum Cholestoral', fontweight='regular', fontsize=11,
           fontfamily='sans-serif', color=black_grad[1])
# --- Q-Q Plot ---
ax_2=fig.add_subplot(2, 2, 4)
plt.title('Q-Q Plot', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[1])
qqplot(df[var], fit=True, line='45', ax=ax_2, markerfacecolor=color, 
       markeredgecolor=color, alpha=0.6)
plt.xlabel('Theoritical Quantiles', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Sample Quantiles', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])

# --- Box Plot ---
ax_3=fig.add_subplot(1, 2, 1)
plt.title('Box Plot', fontweight='bold', fontsize=14, 
          fontfamily='sans-serif', color=black_grad[1])
sns.boxplot(data=df, y=var, color=color, boxprops=dict(alpha=0.8), linewidth=1.5)
plt.ylabel('Serum Cholestoral', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])

plt.show()
# Out:
# .: Serum Cholestoral Column Skewness & Kurtosis :.
# *********************************************
# Skewness: 1.074
# Kurtosis: 3.997

# %% [markdown]
# #### thalach (Maximum Heart Rate)

# %%
# --- Variable, Color & Plot Size ---
var = 'thalach'
color = purple_grad[1]
fig=plt.figure(figsize=(12, 12))

# --- Skewness & Kurtosis ---
print('\033[1m'+'.: Maximum Heart Rate Column Skewness & Kurtosis :.'+'\033[0m')
print('*' * 50)
print('Skewness:'+'\033[1m {:.3f}'.format(df[var].skew(axis = 0, skipna = True)))
print('\033[0m'+'Kurtosis:'+'\033[1m {:.3f}'.format(df[var].kurt(axis = 0, skipna = True)))
print('\n')

# --- General Title ---
fig.suptitle('Maximum Heart Rate Column Distribution', fontweight='bold', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])
fig.subplots_adjust(top=0.9)

# --- Histogram ---
ax_1=fig.add_subplot(2, 2, 2)
plt.title('Histogram Plot', fontweight='bold', fontsize=14, 
          fontfamily='sans-serif', color=black_grad[1])
sns.histplot(data=df, x=var, kde=True, color=color)
plt.xlabel('Total', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Maximum Heart Rate', fontweight='regular', fontsize=11,
           fontfamily='sans-serif', color=black_grad[1])

# --- Q-Q Plot ---
ax_2=fig.add_subplot(2, 2, 4)
plt.title('Q-Q Plot', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[1])
qqplot(df[var], fit=True, line='45', ax=ax_2, markerfacecolor=color, 
       markeredgecolor=color, alpha=0.6)
plt.xlabel('Theoritical Quantiles', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Sample Quantiles', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])

# --- Box Plot ---
ax_3=fig.add_subplot(1, 2, 1)
plt.title('Box Plot', fontweight='bold', fontsize=14, 
          fontfamily='sans-serif', color=black_grad[1])
sns.boxplot(data=df, y=var, color=color, boxprops=dict(alpha=0.8), linewidth=1.5)
plt.ylabel('Maximum Heart Rate', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])

plt.show()
# Out:
# .: Maximum Heart Rate Column Skewness & Kurtosis :.
# **************************************************
# Skewness: -0.514
# Kurtosis: -0.089

# %% [markdown]
# #### oldpeak

# %%
# --- Variable, Color & Plot Size ---
var = 'oldpeak'
color = red_grad[1]
fig=plt.figure(figsize=(12, 12))

# --- Skewness & Kurtosis ---
print('\033[1m'+'.: "oldpeak" Column Skewness & Kurtosis :.'+'\033[0m')
print('*' * 40)
print('Skewness:'+'\033[1m {:.3f}'.format(df[var].skew(axis = 0, skipna = True)))
print('\033[0m'+'Kurtosis:'+'\033[1m {:.3f}'.format(df[var].kurt(axis = 0, skipna = True)))
print('\n')

# --- General Title ---
fig.suptitle('"oldpeak" Column Distribution', fontweight='bold', 
             fontsize=16, fontfamily='sans-serif', color=black_grad[0])
fig.subplots_adjust(top=0.9)

# --- Histogram ---
ax_1=fig.add_subplot(2, 2, 2)
plt.title('Histogram Plot', fontweight='bold', fontsize=14, 
          fontfamily='sans-serif', color=black_grad[1])
sns.histplot(data=df, x=var, kde=True, color=color)
plt.xlabel('Total', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('oldpeak', fontweight='regular', fontsize=11,
           fontfamily='sans-serif', color=black_grad[1])

# --- Q-Q Plot ---
ax_2=fig.add_subplot(2, 2, 4)
plt.title('Q-Q Plot', fontweight='bold', fontsize=14, fontfamily='sans-serif', 
          color=black_grad[1])
qqplot(df[var], fit=True, line='45', ax=ax_2, markerfacecolor=color,
       markeredgecolor=color, alpha=0.6)
plt.xlabel('Theoritical Quantiles', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Sample Quantiles', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])

# --- Box Plot ---
ax_3=fig.add_subplot(1, 2, 1)
plt.title('Box Plot', fontweight='bold', fontsize=14, 
          fontfamily='sans-serif', color=black_grad[1])
sns.boxplot(data=df, y=var, color=color, boxprops=dict(alpha=0.8), linewidth=1.5)
plt.ylabel('oldpeak', fontweight='regular', fontsize=11, 
           fontfamily='sans-serif', color=black_grad[1])

plt.show()
# Out:
# .: "oldpeak" Column Skewness & Kurtosis :.
# ****************************************
# Skewness: 1.211
# Kurtosis: 1.314

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ## Heart Disease Distribution based on Gender

# %%
# --- Labels Settings ---
labels = ['False', 'True']
label_gender = np.array([0, 1])
label_gender2 = ['Male', 'Female']

# --- Creating Bar Chart ---
ax = pd.crosstab(df.sex, df.target).plot(kind='bar', figsize=(8, 5), 
                                         color=color_mix[2:4], 
                                         edgecolor=black_grad[2], alpha=0.85)
# --- Bar Chart Settings ---
for rect in ax.patches:
    ax.text (rect.get_x()+rect.get_width()/2, 
             rect.get_height()+1.25,rect.get_height(), 
             horizontalalignment='center', fontsize=10)

plt.suptitle('Heart Disease Distribution based on Gender', fontweight='heavy', 
             x=0.065, y=0.98, ha='left', fontsize='16', fontfamily='sans-serif', 
             color=black_grad[0])
plt.title('Female tend to have heart diseases compared to Male. In male, the distribution is not imbalanced compared to female\nthat have almost the same distribution', 
          fontsize='8', fontfamily='sans-serif', loc='left', color=black_grad[1])
plt.tight_layout(rect=[0, 0.04, 1, 1.025])
plt.xlabel('Gender (Sex)', fontfamily='sans-serif', fontweight='bold', 
           color=black_grad[1])
plt.ylabel('Total', fontfamily='sans-serif', fontweight='bold', 
           color=black_grad[1])
plt.xticks(label_gender, label_gender2, rotation=0)
plt.grid(axis='y', alpha=0.4)
plt.grid(axis='x', alpha=0)
plt.legend(labels=labels, title='$\\bf{Target}$', fontsize='8', 
           title_fontsize='9', loc='upper left', frameon=True);

# %% [markdown]
# ## Heart Disease Distribution based on Major Vessels Total

# %%
# --- Labels Settings ---
labels = ['False', 'True']

# --- Creating Horizontal Bar Chart ---
ax = pd.crosstab(df.ca, df.target).plot(kind='barh', figsize=(8, 5), 
                                         color=color_mix[2:4],
                                         edgecolor=black_grad[2], alpha=0.85)
# --- Horizontal Bar Chart Settings ---
for rect in ax.patches:
    width, height = rect.get_width(), rect.get_height()
    x, y = rect.get_xy()
    ax.text (x+width/2, y+height/2, '{:.0f}'.format(width), 
             horizontalalignment='center', verticalalignment='center')

plt.suptitle('Heart Disease Distribution based on Major Vessels Total', 
             fontweight='heavy', x=0.069, y=0.98, ha='left', fontsize='16', 
             fontfamily='sans-serif', color=black_grad[0])
plt.title('Patients with 0 and 4 major vessels tend to have heart diseases. However, patients who have a number of vessels 1 to 3\ntend not to have heart diseases.', 
          fontsize='8', fontfamily='sans-serif', loc='left', color=black_grad[1])
plt.tight_layout(rect=[0, 0.04, 1, 1.025])
plt.xlabel('Total', fontfamily='sans-serif', fontweight='bold', color=black_grad[1])
plt.ylabel('Number of Major Vessels', fontfamily='sans-serif', fontweight='bold', 
           color=black_grad[1])
plt.yticks(rotation=0)
plt.grid(axis='x', alpha=0.4)
plt.grid(axis='y', alpha=0)
plt.legend(labels=labels, title='$\\bf{Target}$', fontsize='8', frameon=True,
           title_fontsize='9', loc='upper right');

# %% [markdown]
# ## Heart Disease Scatter Plot based on Age

# %%
# -- Scatter Plot Size & Titles Settings ---
plt.figure(figsize=(10, 8))
plt.suptitle('Heart Disease Scatter Plot based on Age', fontweight='heavy', 
             x=0.048, y=0.98, ha='left', fontsize='16', fontfamily='sans-serif', 
             color=black_grad[0])
plt.title('Based on age, patients with and without heart diseases mostly between 50-70 years old. Patients with heart diseases tend to have high heart rate\ncompared to patients with no heart diseases.', 
          fontsize='8', fontfamily='sans-serif', loc='left', color=black_grad[1])
plt.tight_layout(rect=[0, 0.04, 1, 1.01])

# --- Creating Scatter Plot ---
plt.scatter(x=df.age[df.target==0], y=df.thalach[(df.target==0)], c=pink_grad[0])
plt.scatter(x=df.age[df.target==1], y=df.thalach[(df.target==1)], c=pink_grad[2])

# --- Scatter Plot Legend & Labels Settings ---
plt.legend(['False', 'True'], title='$\\bf{Type}$', fontsize='7', 
           title_fontsize='8', loc='upper right', frameon=True)
plt.xlabel('Age', fontweight='bold', fontsize='11',
           fontfamily='sans-serif', color=black_grad[1])
plt.ylabel('Max. Heart Rate', fontweight='bold', fontsize='11', 
           fontfamily='sans-serif', color=black_grad[1])
plt.ticklabel_format(style='plain', axis='both')
plt.grid(axis='both', alpha=0.4, lw=0.5)
plt.show();

# %% [markdown]
# ## Heatmap

# %%
# --- Correlation Map (Heatmap) ---
plt.figure(figsize=(14, 9))
sns.heatmap(df.corr(), annot=True, cmap='Reds', linewidths=0.1)
plt.suptitle('Correlation Map of Numerical Variables', fontweight='heavy', 
             x=0.03, y=0.98, ha='left', fontsize='16', fontfamily='sans-serif', 
             color=black_grad[0])
plt.title('Resting blood pressure, cholestoral, and "oldpeak" have moderate relationship with age.', 
          fontsize='10', fontfamily='sans-serif', loc='left', color=black_grad[1])
plt.tight_layout(rect=[0, 0.04, 1, 1.01])

# %%
# !pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in e:\programs\anaconda3\envs\heart\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in e:\programs\anaconda3\envs\heart\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\programs\anaconda3\envs\heart\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\programs\anaconda3\envs\heart\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\programs\anaconda3\envs\heart\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in e:\programs\anaconda3\envs\heart\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# # Dataset Pre-processing

# %%
# --- Display New Data Frame ---
styled_df = df.head().style.background_gradient(cmap='Reds') \
    .set_properties(**{'font-family': 'Segoe UI'}) \
    .set_table_styles(
        [{'selector': 'thead th:first-child', 'props': [('display', 'none')]},
         {'selector': 'tbody th', 'props': [('display', 'none')]}]
    )

# Display styled DataFrame
styled_df
# Out:
# <style type="text/css">
# #T_18cdf thead th:first-child {
#   display: none;
# }
# #T_18cdf tbody th {
#   display: none;
# }
# #T_18cdf_row0_col0, #T_18cdf_row0_col3, #T_18cdf_row0_col13, #T_18cdf_row1_col13, #T_18cdf_row2_col4, #T_18cdf_row2_col13, #T_18cdf_row3_col9, #T_18cdf_row3_col13, #T_18cdf_row4_col7, #T_18cdf_row4_col13 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_18cdf_row0_col1, #T_18cdf_row0_col2, #T_18cdf_row0_col5, #T_18cdf_row0_col6, #T_18cdf_row0_col8, #T_18cdf_row0_col10, #T_18cdf_row0_col11, #T_18cdf_row0_col12, #T_18cdf_row1_col1, #T_18cdf_row1_col2, #T_18cdf_row1_col5, #T_18cdf_row1_col6, #T_18cdf_row1_col8, #T_18cdf_row1_col10, #T_18cdf_row1_col11, #T_18cdf_row1_col12, #T_18cdf_row2_col1, #T_18cdf_row2_col2, #T_18cdf_row2_col5, #T_18cdf_row2_col6, #T_18cdf_row2_col8, #T_18cdf_row2_col10, #T_18cdf_row2_col11, #T_18cdf_row2_col12, #T_18cdf_row3_col1, #T_18cdf_row3_col2, #T_18cdf_row3_col5, #T_18cdf_row3_col6, #T_18cdf_row3_col8, #T_18cdf_row3_col10, #T_18cdf_row3_col11, #T_18cdf_row3_col12, #T_18cdf_row4_col1, #T_18cdf_row4_col2, #T_18cdf_row4_col5, #T_18cdf_row4_col6, #T_18cdf_row4_col8, #T_18cdf_row4_col10, #T_18cdf_row4_col11, #T_18cdf_row4_col12 {
#   font-family: Segoe UI;
# }
# #T_18cdf_row0_col4 {
#   background-color: #fca588;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_18cdf_row0_col7, #T_18cdf_row1_col9, #T_18cdf_row2_col0, #T_18cdf_row3_col3, #T_18cdf_row4_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_18cdf_row0_col9 {
#   background-color: #fca486;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_18cdf_row1_col0 {
#   background-color: #ffece3;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_18cdf_row1_col3 {
#   background-color: #e83429;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_18cdf_row1_col4, #T_18cdf_row3_col4 {
#   background-color: #fcbea5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_18cdf_row1_col7 {
#   background-color: #be151a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_18cdf_row2_col3 {
#   background-color: #a60f15;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_18cdf_row2_col7 {
#   background-color: #fca98c;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_18cdf_row2_col9 {
#   background-color: #b01217;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_18cdf_row3_col0 {
#   background-color: #fb694a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_18cdf_row3_col7 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_18cdf_row4_col0 {
#   background-color: #f6553c;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_18cdf_row4_col3 {
#   background-color: #f5523a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_18cdf_row4_col9 {
#   background-color: #f0402f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_18cdf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18cdf_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_18cdf_level0_col1" class="col_heading level0 col1" >sex</th>
#       <th id="T_18cdf_level0_col2" class="col_heading level0 col2" >cp</th>
#       <th id="T_18cdf_level0_col3" class="col_heading level0 col3" >trestbps</th>
#       <th id="T_18cdf_level0_col4" class="col_heading level0 col4" >chol</th>
#       <th id="T_18cdf_level0_col5" class="col_heading level0 col5" >fbs</th>
#       <th id="T_18cdf_level0_col6" class="col_heading level0 col6" >restecg</th>
#       <th id="T_18cdf_level0_col7" class="col_heading level0 col7" >thalach</th>
#       <th id="T_18cdf_level0_col8" class="col_heading level0 col8" >exang</th>
#       <th id="T_18cdf_level0_col9" class="col_heading level0 col9" >oldpeak</th>
#       <th id="T_18cdf_level0_col10" class="col_heading level0 col10" >slope</th>
#       <th id="T_18cdf_level0_col11" class="col_heading level0 col11" >ca</th>
#       <th id="T_18cdf_level0_col12" class="col_heading level0 col12" >thal</th>
#       <th id="T_18cdf_level0_col13" class="col_heading level0 col13" >target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18cdf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18cdf_row0_col0" class="data row0 col0" >52</td>
#       <td id="T_18cdf_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_18cdf_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_18cdf_row0_col3" class="data row0 col3" >125</td>
#       <td id="T_18cdf_row0_col4" class="data row0 col4" >212</td>
#       <td id="T_18cdf_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_18cdf_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_18cdf_row0_col7" class="data row0 col7" >168</td>
#       <td id="T_18cdf_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_18cdf_row0_col9" class="data row0 col9" >1.000000</td>
#       <td id="T_18cdf_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_18cdf_row0_col11" class="data row0 col11" >2</td>
#       <td id="T_18cdf_row0_col12" class="data row0 col12" >3</td>
#       <td id="T_18cdf_row0_col13" class="data row0 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_18cdf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_18cdf_row1_col0" class="data row1 col0" >53</td>
#       <td id="T_18cdf_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_18cdf_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_18cdf_row1_col3" class="data row1 col3" >140</td>
#       <td id="T_18cdf_row1_col4" class="data row1 col4" >203</td>
#       <td id="T_18cdf_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_18cdf_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_18cdf_row1_col7" class="data row1 col7" >155</td>
#       <td id="T_18cdf_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_18cdf_row1_col9" class="data row1 col9" >3.100000</td>
#       <td id="T_18cdf_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_18cdf_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_18cdf_row1_col12" class="data row1 col12" >3</td>
#       <td id="T_18cdf_row1_col13" class="data row1 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_18cdf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_18cdf_row2_col0" class="data row2 col0" >70</td>
#       <td id="T_18cdf_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_18cdf_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_18cdf_row2_col3" class="data row2 col3" >145</td>
#       <td id="T_18cdf_row2_col4" class="data row2 col4" >174</td>
#       <td id="T_18cdf_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_18cdf_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_18cdf_row2_col7" class="data row2 col7" >125</td>
#       <td id="T_18cdf_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_18cdf_row2_col9" class="data row2 col9" >2.600000</td>
#       <td id="T_18cdf_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_18cdf_row2_col11" class="data row2 col11" >0</td>
#       <td id="T_18cdf_row2_col12" class="data row2 col12" >3</td>
#       <td id="T_18cdf_row2_col13" class="data row2 col13" >0</td>
#     </tr>
#     <tr>
#       <th id="T_18cdf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_18cdf_row3_col0" class="data row3 col0" >61</td>
#       <td id="T_18cdf_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_18cdf_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_18cdf_row3_col3" class="data row3 col3" >148</td>
#       <td id="T_18cdf_row3_col4" class="data row3 col4" >203</td>
#       <td id="T_18cdf_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_18cdf_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_18cdf_row3_col7" class="data row3 col7" >161</td>
#       <td id="T_18cdf_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_18cdf_row3_col9" class="data row3 col9" >0.000000</td>
#       <td id="T_18cdf_row3_col10" class="data row3 col10" >2</td>
#       <td id="T_18cdf_row3_col11" class="data row3 col11" >1</td>
#       <td id="T_18cdf_row3_col12" class="data row3 col12" >3</td>
#       <td id="T_18cdf_row3_col13

# %% [markdown]
# ## Features Separating

# %%
# --- Seperating Dependent Features ---
x = df.drop(['target'], axis=1)
print(len(x))
y = df['target']

# --- Display New Data Frame ---
styled_x = x.head().style.background_gradient(cmap='Reds') \
    .set_properties(**{'font-family': 'Segoe UI'}) \
    .set_table_styles(
        [{'selector': 'thead th:first-child', 'props': [('display', 'none')]},
         {'selector': 'tbody th', 'props': [('display', 'none')]}]
    )

# Display styled DataFrame
styled_x
# Out:
# 1025
# <style type="text/css">
# #T_436a5 thead th:first-child {
#   display: none;
# }
# #T_436a5 tbody th {
#   display: none;
# }
# #T_436a5_row0_col0, #T_436a5_row0_col3, #T_436a5_row2_col4, #T_436a5_row3_col9, #T_436a5_row4_col7 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_436a5_row0_col1, #T_436a5_row0_col2, #T_436a5_row0_col5, #T_436a5_row0_col6, #T_436a5_row0_col8, #T_436a5_row0_col10, #T_436a5_row0_col11, #T_436a5_row0_col12, #T_436a5_row1_col1, #T_436a5_row1_col2, #T_436a5_row1_col5, #T_436a5_row1_col6, #T_436a5_row1_col8, #T_436a5_row1_col10, #T_436a5_row1_col11, #T_436a5_row1_col12, #T_436a5_row2_col1, #T_436a5_row2_col2, #T_436a5_row2_col5, #T_436a5_row2_col6, #T_436a5_row2_col8, #T_436a5_row2_col10, #T_436a5_row2_col11, #T_436a5_row2_col12, #T_436a5_row3_col1, #T_436a5_row3_col2, #T_436a5_row3_col5, #T_436a5_row3_col6, #T_436a5_row3_col8, #T_436a5_row3_col10, #T_436a5_row3_col11, #T_436a5_row3_col12, #T_436a5_row4_col1, #T_436a5_row4_col2, #T_436a5_row4_col5, #T_436a5_row4_col6, #T_436a5_row4_col8, #T_436a5_row4_col10, #T_436a5_row4_col11, #T_436a5_row4_col12 {
#   font-family: Segoe UI;
# }
# #T_436a5_row0_col4 {
#   background-color: #fca588;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_436a5_row0_col7, #T_436a5_row1_col9, #T_436a5_row2_col0, #T_436a5_row3_col3, #T_436a5_row4_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_436a5_row0_col9 {
#   background-color: #fca486;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_436a5_row1_col0 {
#   background-color: #ffece3;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_436a5_row1_col3 {
#   background-color: #e83429;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_436a5_row1_col4, #T_436a5_row3_col4 {
#   background-color: #fcbea5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_436a5_row1_col7 {
#   background-color: #be151a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_436a5_row2_col3 {
#   background-color: #a60f15;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_436a5_row2_col7 {
#   background-color: #fca98c;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_436a5_row2_col9 {
#   background-color: #b01217;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_436a5_row3_col0 {
#   background-color: #fb694a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_436a5_row3_col7 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_436a5_row4_col0 {
#   background-color: #f6553c;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_436a5_row4_col3 {
#   background-color: #f5523a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_436a5_row4_col9 {
#   background-color: #f0402f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_436a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_436a5_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_436a5_level0_col1" class="col_heading level0 col1" >sex</th>
#       <th id="T_436a5_level0_col2" class="col_heading level0 col2" >cp</th>
#       <th id="T_436a5_level0_col3" class="col_heading level0 col3" >trestbps</th>
#       <th id="T_436a5_level0_col4" class="col_heading level0 col4" >chol</th>
#       <th id="T_436a5_level0_col5" class="col_heading level0 col5" >fbs</th>
#       <th id="T_436a5_level0_col6" class="col_heading level0 col6" >restecg</th>
#       <th id="T_436a5_level0_col7" class="col_heading level0 col7" >thalach</th>
#       <th id="T_436a5_level0_col8" class="col_heading level0 col8" >exang</th>
#       <th id="T_436a5_level0_col9" class="col_heading level0 col9" >oldpeak</th>
#       <th id="T_436a5_level0_col10" class="col_heading level0 col10" >slope</th>
#       <th id="T_436a5_level0_col11" class="col_heading level0 col11" >ca</th>
#       <th id="T_436a5_level0_col12" class="col_heading level0 col12" >thal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_436a5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_436a5_row0_col0" class="data row0 col0" >52</td>
#       <td id="T_436a5_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_436a5_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_436a5_row0_col3" class="data row0 col3" >125</td>
#       <td id="T_436a5_row0_col4" class="data row0 col4" >212</td>
#       <td id="T_436a5_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_436a5_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_436a5_row0_col7" class="data row0 col7" >168</td>
#       <td id="T_436a5_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_436a5_row0_col9" class="data row0 col9" >1.000000</td>
#       <td id="T_436a5_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_436a5_row0_col11" class="data row0 col11" >2</td>
#       <td id="T_436a5_row0_col12" class="data row0 col12" >3</td>
#     </tr>
#     <tr>
#       <th id="T_436a5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_436a5_row1_col0" class="data row1 col0" >53</td>
#       <td id="T_436a5_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_436a5_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_436a5_row1_col3" class="data row1 col3" >140</td>
#       <td id="T_436a5_row1_col4" class="data row1 col4" >203</td>
#       <td id="T_436a5_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_436a5_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_436a5_row1_col7" class="data row1 col7" >155</td>
#       <td id="T_436a5_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_436a5_row1_col9" class="data row1 col9" >3.100000</td>
#       <td id="T_436a5_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_436a5_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_436a5_row1_col12" class="data row1 col12" >3</td>
#     </tr>
#     <tr>
#       <th id="T_436a5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_436a5_row2_col0" class="data row2 col0" >70</td>
#       <td id="T_436a5_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_436a5_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_436a5_row2_col3" class="data row2 col3" >145</td>
#       <td id="T_436a5_row2_col4" class="data row2 col4" >174</td>
#       <td id="T_436a5_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_436a5_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_436a5_row2_col7" class="data row2 col7" >125</td>
#       <td id="T_436a5_row2_col8" class="data row2 col8" >1</td>
#       <td id="T_436a5_row2_col9" class="data row2 col9" >2.600000</td>
#       <td id="T_436a5_row2_col10" class="data row2 col10" >0</td>
#       <td id="T_436a5_row2_col11" class="data row2 col11" >0</td>
#       <td id="T_436a5_row2_col12" class="data row2 col12" >3</td>
#     </tr>
#     <tr>
#       <th id="T_436a5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_436a5_row3_col0" class="data row3 col0" >61</td>
#       <td id="T_436a5_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_436a5_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_436a5_row3_col3" class="data row3 col3" >148</td>
#       <td id="T_436a5_row3_col4" class="data row3 col4" >203</td>
#       <td id="T_436a5_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_436a5_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_436a5_row3_col7" class="data row3 col7" >161</td>
#       <td id="T_436a5_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_436a5_row3_col9" class="data row3 col9" >0.000000</td>
#       <td id="T_436a5_row3_col10" class="data row3 col10" >2</td>
#       <td id="T_436a5_row3_col11" class="data row3 col11" >1</td>
#       <td id="T_436a5_row3_col12" class="data row3 col12" >3</td>
#     </tr>
#     <tr>
#       <th id="T_436a5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_436a5_row4_col0" class="data row4 col0" >62</td>
#       <td id="T_436a5_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_436a5_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_436a5_row4_col3" class="data row4 col3" >138</td>
#       <td id="T_436a5_row4_col4" class="data row4 col4" >294</td

# %% [markdown]
# ## Data Normalization

# %%
# --- Data Normalization using Min-Max Method ---
# x = MinMaxScaler().fit_transform(x)
x = Normalizer().fit_transform(x)

# %%
print(np.size(x))
# Out:
# 13325

# %% [markdown]
# # Model Implementation

# %%
# --- Splitting Dataset into 80:20 ---
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=4)

print(len(x_train))
# Out:
# 820

# %% [markdown]
# ## Logistic Regression

# %%
# --- Applying Logistic Regression ---
LRclassifier = LogisticRegression(max_iter=1000, random_state=1, solver='liblinear', penalty='l1')
LRclassifier.fit(x_train, y_train)

y_pred_LR = LRclassifier.predict(x_test)

# %% [markdown]
# # --- LR Accuracy ---

# %%
LRAcc = accuracy_score(y_test, y_pred_LR)
LR_precision = precision_score(y_test, y_pred_LR)
LR_recall = recall_score(y_test, y_pred_LR)
LR_f1 = f1_score(y_test, y_pred_LR)
LR_cm = confusion_matrix(y_test, y_pred_LR)
print('.:. Logistic Regression Accuracy:'+'\033[1m {:.2f}%'.format(LRAcc*100)+' .:.')

print("\033[1mLogistic Regression Evaluation Metrics:\033[0m")
print(f"Accuracy: \033[1m{LRAcc * 100:.2f}%\033[0m")
print(f"Precision: \033[1m{LR_precision:.2f}\033[0m")  # Measures false positives
print(f"Recall (Sensitivity): \033[1m{LR_recall:.2f}\033[0m")  # Measures false negatives
print(f"F1-Score: \033[1m{LR_f1:.2f}\033[0m")  # Harmonic mean of precision & recall
# Out:
# .:. Logistic Regression Accuracy: 66.83% .:.
# Logistic Regression Evaluation Metrics:
# Accuracy: 66.83%
# Precision: 0.63
# Recall (Sensitivity): 0.73
# F1-Score: 0.68

# %% [markdown]
# ### Save training model

# %%
with open('./models/LRclassifier.pkl','wb') as f:
    pickle.dump(LRclassifier,f)
    

with open('./results/LRclassifier_Accuracy.pkl','wb') as fa:
    pickle.dump(LRAcc,fa)

# %% [markdown]
# ## K-Nearest Neighbour (KNN)

# %%
# --- Applying KNN ---
KNNClassifier = KNeighborsClassifier(n_neighbors=3)
KNNClassifier.fit(x_train, y_train)

y_pred_KNN = KNNClassifier.predict(x_test)

# %% [markdown]
# # --- KNN Accuracy ---

# %%
KNNAcc = accuracy_score(y_test, y_pred_KNN)
KNN_precision = precision_score(y_test, y_pred_KNN)
KNN_recall = recall_score(y_test, y_pred_KNN)
KNN_f1 = f1_score(y_test, y_pred_KNN)
KNN_cm = confusion_matrix(y_test, y_pred_KNN)
print('.:. K-Nearest Neighbour Accuracy:'+'\033[1m {:.2f}%'.format(KNNAcc*100)+' .:.')

print("\033[1mK-Nearest Neighbour Evaluation Metrics:\033[0m")
print(f"Accuracy: \033[1m{KNNAcc * 100:.2f}%\033[0m")
print(f"Precision: \033[1m{KNN_precision:.2f}\033[0m")  # Measures false positives
print(f"Recall (Sensitivity): \033[1m{KNN_recall:.2f}\033[0m")  # Measures false negatives
print(f"F1-Score: \033[1m{KNN_f1:.2f}\033[0m")  # Harmonic mean of precision & recall

print("\n\033[1mConfusion Matrix:\033[0m")
print(KNN_cm)
# Out:
# .:. K-Nearest Neighbour Accuracy: 95.61% .:.
# K-Nearest Neighbour Evaluation Metrics:
# Accuracy: 95.61%
# Precision: 0.93
# Recall (Sensitivity): 0.98
# F1-Score: 0.96
#
# Confusion Matrix:
# [[100   7]
#  [  2  96]]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

disp = ConfusionMatrixDisplay(confusion_matrix=KNN_cm)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %%
with open('./models/KNNClassifier.pkl','wb') as f:
    pickle.dump(KNNClassifier,f)
    

with open('./results/KNNClassifier_Accuracy.pkl','wb') as fa:
    pickle.dump(KNNAcc,fa)

# %% [markdown]
# ## Support Vector Machine (SVM)

# %%
# --- Applying SVM ---
SVMclassifier = SVC(kernel='linear', max_iter=1000, C=10, probability=True)
SVMclassifier.fit(x_train, y_train)

y_pred_SVM = SVMclassifier.predict(x_test)

# %% [markdown]
# # --- SVM Accuracy ---

# %%
SVMAcc = accuracy_score(y_test, y_pred_SVM)
SVM_precision = precision_score(y_test, y_pred_SVM)
SVM_recall = recall_score(y_test, y_pred_SVM)
SVM_f1 = f1_score(y_test, y_pred_SVM)
SVM_cm = confusion_matrix(y_test, y_pred_SVM)
print('.:. Support Vector Machine Accuracy:'+'\033[1m {:.2f}%'.format(SVMAcc*100)+' .:.')

print("\033[1mSupport Vector Machine Evaluation Metrics:\033[0m")
print(f"Accuracy: \033[1m{SVMAcc * 100:.2f}%\033[0m")
print(f"Precision: \033[1m{SVM_precision:.2f}\033[0m")  # Measures false positives
print(f"Recall (Sensitivity): \033[1m{SVM_recall:.2f}\033[0m")  # Measures false negatives
print(f"F1-Score: \033[1m{SVM_f1:.2f}\033[0m")  # Harmonic mean of precision & recall
# Out:
# .:. Support Vector Machine Accuracy: 68.29% .:.
# Support Vector Machine Evaluation Metrics:
# Accuracy: 68.29%
# Precision: 0.66
# Recall (Sensitivity): 0.70
# F1-Score: 0.68

# %%
with open('./models/SVMclassifier.pkl','wb') as f:
    pickle.dump(SVMclassifier,f)
    

with open('./results/SVMclassifier_Accuracy.pkl','wb') as fa:
    pickle.dump(SVMAcc,fa)

# %% [markdown]
# ## Gaussian Naive Bayes

# %%
# --- Applying Gaussian NB ---
GNBclassifier = GaussianNB(var_smoothing=0.1)
GNBclassifier.fit(x_train, y_train)

y_pred_GNB = GNBclassifier.predict(x_test)

# %% [markdown]
# # --- GNB Accuracy ---

# %%
GNBAcc = accuracy_score(y_test, y_pred_GNB)
GNB_precision = precision_score(y_test, y_pred_GNB)
GNB_recall = recall_score(y_test, y_pred_GNB)
GNB_f1 = f1_score(y_test, y_pred_GNB)
GNB_cm = confusion_matrix(y_test, y_pred_GNB)
print('.:. Gaussian Naive Baiyes Accuracy:'+'\033[1m {:.2f}%'.format(GNBAcc*100)+' .:.')

print("\033[1mGaussian Naive Bayes Evaluation Metrics:\033[0m")
print(f"Accuracy: \033[1m{GNBAcc * 100:.2f}%\033[0m")
print(f"Precision: \033[1m{GNB_precision:.2f}\033[0m")  # Measures false positives
print(f"Recall (Sensitivity): \033[1m{GNB_recall:.2f}\033[0m")  # Measures false negatives
print(f"F1-Score: \033[1m{GNB_f1:.2f}\033[0m")  # Harmonic mean of precision & recall
# Out:
# .:. Gaussian Naive Baiyes Accuracy: 63.41% .:.
# Gaussian Naive Bayes Evaluation Metrics:
# Accuracy: 63.41%
# Precision: 0.61
# Recall (Sensitivity): 0.65
# F1-Score: 0.63

# %%
with open('./models/GNBclassifier.pkl','wb') as f:
    pickle.dump(GNBclassifier,f)
    

with open('./results/GNBclassifier_Accuracy.pkl','wb') as fa:
    pickle.dump(GNBAcc,fa)

# %% [markdown]
# ## Decision Tree

# %%
# --- Applying Decision Tree ---
DTCclassifier = DecisionTreeClassifier(max_depth=3, min_samples_leaf=5, criterion='entropy', min_samples_split=5,
                                       splitter='random', random_state=1)

DTCclassifier.fit(x_train, y_train)
y_pred_DTC = DTCclassifier.predict(x_test)

# %% [markdown]
# # --- Decision Tree Accuracy ---

# %%
DTCAcc = accuracy_score(y_test, y_pred_DTC)
DTC_precision = precision_score(y_test, y_pred_DTC)
DTC_recall = recall_score(y_test, y_pred_DTC)
DTC_f1 = f1_score(y_test, y_pred_DTC)
DTC_cm = confusion_matrix(y_test, y_pred_DTC)
print('.:. Decision Tree Accuracy:'+'\033[1m {:.2f}%'.format(DTCAcc*100)+' .:.')

print("\033[1mDecision Tree Evaluation Metrics:\033[0m")
print(f"Accuracy: \033[1m{DTCAcc * 100:.2f}%\033[0m")
print(f"Precision: \033[1m{DTC_precision:.2f}\033[0m")  # Measures false positives
print(f"Recall (Sensitivity): \033[1m{DTC_recall:.2f}\033[0m")  # Measures false negatives
print(f"F1-Score: \033[1m{DTC_f1:.2f}\033[0m")  # Harmonic mean of precision & recall
# Out:
# .:. Decision Tree Accuracy: 79.02% .:.
# Decision Tree Evaluation Metrics:
# Accuracy: 79.02%
# Precision: 0.74
# Recall (Sensitivity): 0.86
# F1-Score: 0.80

# %%
with open('./models/DTCclassifier.pkl','wb') as f:
    pickle.dump(DTCclassifier,f)
    

with open('./results/DTCclassifier_Accuracy.pkl','wb') as fa:
    pickle.dump(DTCAcc,fa)

# %% [markdown]
# ## Random Forest

# %%
# --- Applying Random Forest ---
RFclassifier = RandomForestClassifier(n_estimators=1000, random_state=1, max_leaf_nodes=20, min_samples_split=15)

RFclassifier.fit(x_train, y_train)
y_pred_RF = RFclassifier.predict(x_test)

# %% [markdown]
# # --- Random Forest Accuracy ---

# %%
RFAcc = accuracy_score(y_test, y_pred_RF)
RF_precision = precision_score(y_test, y_pred_RF)
RF_recall = recall_score(y_test, y_pred_RF)
RF_f1 = f1_score(y_test, y_pred_RF)
RF_cm = confusion_matrix(y_test, y_pred_RF)
print('.:. Random Forest Accuracy:'+'\033[1m {:.2f}%'.format(RFAcc*100)+' .:.')

print("\033[1mRandom Forest Evaluation Metrics:\033[0m")
print(f"Accuracy: \033[1m{RFAcc * 100:.2f}%\033[0m")
print(f"Precision: \033[1m{RF_precision:.2f}\033[0m")  # Measures false positives
print(f"Recall (Sensitivity): \033[1m{RF_recall:.2f}\033[0m")  # Measures false negatives
print(f"F1-Score: \033[1m{RF_f1:.2f}\033[0m")  # Harmonic mean of precision & recall
# Out:
# .:. Random Forest Accuracy: 90.24% .:.
# Random Forest Evaluation Metrics:
# Accuracy: 90.24%
# Precision: 0.86
# Recall (Sensitivity): 0.95
# F1-Score: 0.90

# %%
with open('./models/RFclassifier.pkl','wb') as f:
    pickle.dump(RFclassifier,f)
    

with open('./results/RFclassifier_Accuracy.pkl','wb') as fa:
    pickle.dump(RFAcc,fa)

# %% [markdown]
# ## Gradient Boosting

# %%
# --- Applying Gradient Boosting ---
GBclassifier = GradientBoostingClassifier(random_state=1, n_estimators=100, max_leaf_nodes=3, loss='exponential', 
                                          min_samples_leaf=20)

GBclassifier.fit(x_train, y_train)
y_pred_GB = GBclassifier.predict(x_test)

# %% [markdown]
# # --- Gradient Boosting Accuracy ---

# %%
GBAcc = accuracy_score(y_test, y_pred_GB)
GB_precision = precision_score(y_test, y_pred_GB)
GB_recall = recall_score(y_test, y_pred_GB)
GB_f1 = f1_score(y_test, y_pred_GB)
GB_cm = confusion_matrix(y_test, y_pred_GB)
print('.:. Gradient Boosting Accuracy:'+'\033[1m {:.2f}%'.format(GBAcc*100)+' .:.')

print("\033[1mGradient Boosting Evaluation Metrics:\033[0m")
print(f"Accuracy: \033[1m{GBAcc * 100:.2f}%\033[0m")
print(f"Precision: \033[1m{GB_precision:.2f}\033[0m")  # Measures false positives
print(f"Recall (Sensitivity): \033[1m{GB_recall:.2f}\033[0m")  # Measures false negatives
print(f"F1-Score: \033[1m{GB_f1:.2f}\033[0m")  # Harmonic mean of precision & recall
# Out:
# .:. Gradient Boosting Accuracy: 90.24% .:.
# Gradient Boosting Evaluation Metrics:
# Accuracy: 90.24%
# Precision: 0.86
# Recall (Sensitivity): 0.95
# F1-Score: 0.90

# %%
with open('./models/GBclassifier.pkl','wb') as f:
    pickle.dump(GBclassifier,f)
    

with open('./results/GBclassifier_Accuracy.pkl','wb') as fa:
    pickle.dump(GBAcc,fa)

# %% [markdown]
# ## Model Comparison

# %%
# --- Create Accuracy Comparison Table ---
compare = pd.DataFrame({
    'Model': ['Logistic Regression', 'K-Nearest Neighbour', 'Support Vector Machine', 
              'Gaussian Naive Bayes', 'Decision Tree', 'Random Forest', 'Gradient Boosting'], 
    'Accuracy': [LRAcc*100, KNNAcc*100, SVMAcc*100, GNBAcc*100, DTCAcc*100, RFAcc*100, GBAcc*100]
})

# --- Create Accuracy Comparison Table ---
styled_compare = compare.sort_values(by='Accuracy', ascending=False).style.background_gradient(cmap='PuRd') \
    .set_properties(**{'font-family': 'Segoe UI'}) \
    .set_table_styles(
        [{'selector': 'thead th:first-child', 'props': [('display', 'none')]},
         {'selector': 'tbody th', 'props': [('display', 'none')]}]
    )

# Display styled DataFrame
styled_compare
# Out:
# <style type="text/css">
# #T_8e1b9 thead th:first-child {
#   display: none;
# }
# #T_8e1b9 tbody th {
#   display: none;
# }
# #T_8e1b9_row0_col0, #T_8e1b9_row1_col0, #T_8e1b9_row2_col0, #T_8e1b9_row3_col0, #T_8e1b9_row4_col0, #T_8e1b9_row5_col0, #T_8e1b9_row6_col0 {
#   font-family: Segoe UI;
# }
# #T_8e1b9_row0_col1 {
#   background-color: #67001f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_8e1b9_row1_col1, #T_8e1b9_row2_col1 {
#   background-color: #a90649;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_8e1b9_row3_col1 {
#   background-color: #dd6ab3;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_8e1b9_row4_col1 {
#   background-color: #e3d9eb;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8e1b9_row5_col1 {
#   background-color: #e9e4f1;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_8e1b9_row6_col1 {
#   background-color: #f7f4f9;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_8e1b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e1b9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8e1b9_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e1b9_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8e1b9_row0_col0" class="data row0 col0" >K-Nearest Neighbour</td>
#       <td id="T_8e1b9_row0_col1" class="data row0 col1" >95.609756</td>
#     </tr>
#     <tr>
#       <th id="T_8e1b9_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_8e1b9_row1_col0" class="data row1 col0" >Random Forest</td>
#       <td id="T_8e1b9_row1_col1" class="data row1 col1" >90.243902</td>
#     </tr>
#     <tr>
#       <th id="T_8e1b9_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_8e1b9_row2_col0" class="data row2 col0" >Gradient Boosting</td>
#       <td id="T_8e1b9_row2_col1" class="data row2 col1" >90.243902</td>
#     </tr>
#     <tr>
#       <th id="T_8e1b9_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_8e1b9_row3_col0" class="data row3 col0" >Decision Tree</td>
#       <td id="T_8e1b9_row3_col1" class="data row3 col1" >79.024390</td>
#     </tr>
#     <tr>
#       <th id="T_8e1b9_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_8e1b9_row4_col0" class="data row4 col0" >Support Vector Machine</td>
#       <td id="T_8e1b9_row4_col1" class="data row4 col1" >68.292683</td>
#     </tr>
#     <tr>
#       <th id="T_8e1b9_level0_row5" class="row_heading level0 row5" >0</th>
#       <td id="T_8e1b9_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_8e1b9_row5_col1" class="data row5 col1" >66.829268</td>
#     </tr>
#     <tr>
#       <th id="T_8e1b9_level0_row6" class="row_heading level0 row6" >3</th>
#       <td id="T_8e1b9_row6_col0" class="data row6 col0" >Gaussian Naive Bayes</td>
#       <td id="T_8e1b9_row6_col1" class="data row6 col1" >63.414634</td>
#     </tr>
#   </tbody>
# </table>

# %%
# --- Create Precision Comparison Table ---
compare = pd.DataFrame({
    'Model': ['Logistic Regression', 'K-Nearest Neighbour', 'Support Vector Machine', 
              'Gaussian Naive Bayes', 'Decision Tree', 'Random Forest', 'Gradient Boosting'], 
    'Precision': [LR_precision*100, KNN_precision*100, SVM_precision*100, GNB_precision*100, DTC_precision*100, RF_precision*100, GB_precision*100]
})

# --- Create Precision Comparison Table ---
styled_compare = compare.sort_values(by='Precision', ascending=False).style.background_gradient(cmap='PuRd') \
    .set_properties(**{'font-family': 'Segoe UI'}) \
    .set_table_styles(
        [{'selector': 'thead th:first-child', 'props': [('display', 'none')]},
         {'selector': 'tbody th', 'props': [('display', 'none')]}]
    )

# Display styled DataFrame
styled_compare
# Out:
# <style type="text/css">
# #T_5c45e thead th:first-child {
#   display: none;
# }
# #T_5c45e tbody th {
#   display: none;
# }
# #T_5c45e_row0_col0, #T_5c45e_row1_col0, #T_5c45e_row2_col0, #T_5c45e_row3_col0, #T_5c45e_row4_col0, #T_5c45e_row5_col0, #T_5c45e_row6_col0 {
#   font-family: Segoe UI;
# }
# #T_5c45e_row0_col1 {
#   background-color: #67001f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_5c45e_row1_col1, #T_5c45e_row2_col1 {
#   background-color: #c10e51;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_5c45e_row3_col1 {
#   background-color: #d085c0;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_5c45e_row4_col1 {
#   background-color: #e4dbec;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_5c45e_row5_col1 {
#   background-color: #eeeaf4;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_5c45e_row6_col1 {
#   background-color: #f7f4f9;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_5c45e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c45e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5c45e_level0_col1" class="col_heading level0 col1" >Precision</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c45e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_5c45e_row0_col0" class="data row0 col0" >K-Nearest Neighbour</td>
#       <td id="T_5c45e_row0_col1" class="data row0 col1" >93.203883</td>
#     </tr>
#     <tr>
#       <th id="T_5c45e_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_5c45e_row1_col0" class="data row1 col0" >Random Forest</td>
#       <td id="T_5c45e_row1_col1" class="data row1 col1" >86.111111</td>
#     </tr>
#     <tr>
#       <th id="T_5c45e_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_5c45e_row2_col0" class="data row2 col0" >Gradient Boosting</td>
#       <td id="T_5c45e_row2_col1" class="data row2 col1" >86.111111</td>
#     </tr>
#     <tr>
#       <th id="T_5c45e_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_5c45e_row3_col0" class="data row3 col0" >Decision Tree</td>
#       <td id="T_5c45e_row3_col1" class="data row3 col1" >74.336283</td>
#     </tr>
#     <tr>
#       <th id="T_5c45e_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_5c45e_row4_col0" class="data row4 col0" >Support Vector Machine</td>
#       <td id="T_5c45e_row4_col1" class="data row4 col1" >65.714286</td>
#     </tr>
#     <tr>
#       <th id="T_5c45e_level0_row5" class="row_heading level0 row5" >0</th>
#       <td id="T_5c45e_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_5c45e_row5_col1" class="data row5 col1" >63.157895</td>
#     </tr>
#     <tr>
#       <th id="T_5c45e_level0_row6" class="row_heading level0 row6" >3</th>
#       <td id="T_5c45e_row6_col0" class="data row6 col0" >Gaussian Naive Bayes</td>
#       <td id="T_5c45e_row6_col1" class="data row6 col1" >60.952381</td>
#     </tr>
#   </tbody>
# </table>

# %%
# --- Create Recall Comparison Table ---
compare = pd.DataFrame({
    'Model': ['Logistic Regression', 'K-Nearest Neighbour', 'Support Vector Machine', 
              'Gaussian Naive Bayes', 'Decision Tree', 'Random Forest', 'Gradient Boosting'], 
    'Recall': [LR_recall*100, KNN_recall*100, SVM_recall*100, GNB_recall*100, DTC_recall*100, RF_recall*100, GB_recall*100]
})

# --- Create Recall Comparison Table ---
styled_compare = compare.sort_values(by='Recall', ascending=False).style.background_gradient(cmap='PuRd') \
    .set_properties(**{'font-family': 'Segoe UI'}) \
    .set_table_styles(
        [{'selector': 'thead th:first-child', 'props': [('display', 'none')]},
         {'selector': 'tbody th', 'props': [('display', 'none')]}]
    )

# Display styled DataFrame
styled_compare
# Out:
# <style type="text/css">
# #T_4639e thead th:first-child {
#   display: none;
# }
# #T_4639e tbody th {
#   display: none;
# }
# #T_4639e_row0_col0, #T_4639e_row1_col0, #T_4639e_row2_col0, #T_4639e_row3_col0, #T_4639e_row4_col0, #T_4639e_row5_col0, #T_4639e_row6_col0 {
#   font-family: Segoe UI;
# }
# #T_4639e_row0_col1 {
#   background-color: #67001f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_4639e_row1_col1, #T_4639e_row2_col1 {
#   background-color: #8a0039;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_4639e_row3_col1 {
#   background-color: #e72a8a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_4639e_row4_col1 {
#   background-color: #d4b9da;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_4639e_row5_col1 {
#   background-color: #e2d7ea;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_4639e_row6_col1 {
#   background-color: #f7f4f9;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_4639e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4639e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4639e_level0_col1" class="col_heading level0 col1" >Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4639e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_4639e_row0_col0" class="data row0 col0" >K-Nearest Neighbour</td>
#       <td id="T_4639e_row0_col1" class="data row0 col1" >97.959184</td>
#     </tr>
#     <tr>
#       <th id="T_4639e_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_4639e_row1_col0" class="data row1 col0" >Random Forest</td>
#       <td id="T_4639e_row1_col1" class="data row1 col1" >94.897959</td>
#     </tr>
#     <tr>
#       <th id="T_4639e_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_4639e_row2_col0" class="data row2 col0" >Gradient Boosting</td>
#       <td id="T_4639e_row2_col1" class="data row2 col1" >94.897959</td>
#     </tr>
#     <tr>
#       <th id="T_4639e_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_4639e_row3_col0" class="data row3 col0" >Decision Tree</td>
#       <td id="T_4639e_row3_col1" class="data row3 col1" >85.714286</td>
#     </tr>
#     <tr>
#       <th id="T_4639e_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_4639e_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_4639e_row4_col1" class="data row4 col1" >73.469388</td>
#     </tr>
#     <tr>
#       <th id="T_4639e_level0_row5" class="row_heading level0 row5" >2</th>
#       <td id="T_4639e_row5_col0" class="data row5 col0" >Support Vector Machine</td>
#       <td id="T_4639e_row5_col1" class="data row5 col1" >70.408163</td>
#     </tr>
#     <tr>
#       <th id="T_4639e_level0_row6" class="row_heading level0 row6" >3</th>
#       <td id="T_4639e_row6_col0" class="data row6 col0" >Gaussian Naive Bayes</td>
#       <td id="T_4639e_row6_col1" class="data row6 col1" >65.306122</td>
#     </tr>
#   </tbody>
# </table>

# %%
# --- Create f1-score Comparison Table ---
compare = pd.DataFrame({
    'Model': ['Logistic Regression', 'K-Nearest Neighbour', 'Support Vector Machine', 
              'Gaussian Naive Bayes', 'Decision Tree', 'Random Forest', 'Gradient Boosting'], 
    'f1-score': [LR_f1*100, KNN_f1*100, SVM_f1*100, GNB_f1*100, DTC_f1*100, RF_f1*100, GB_f1*100]
})

# --- Create f1-score Comparison Table ---
styled_compare = compare.sort_values(by='f1-score', ascending=False).style.background_gradient(cmap='PuRd') \
    .set_properties(**{'font-family': 'Segoe UI'}) \
    .set_table_styles(
        [{'selector': 'thead th:first-child', 'props': [('display', 'none')]},
         {'selector': 'tbody th', 'props': [('display', 'none')]}]
    )

# Display styled DataFrame
styled_compare
# Out:
# <style type="text/css">
# #T_e81ed thead th:first-child {
#   display: none;
# }
# #T_e81ed tbody th {
#   display: none;
# }
# #T_e81ed_row0_col0, #T_e81ed_row1_col0, #T_e81ed_row2_col0, #T_e81ed_row3_col0, #T_e81ed_row4_col0, #T_e81ed_row5_col0, #T_e81ed_row6_col0 {
#   font-family: Segoe UI;
# }
# #T_e81ed_row0_col1 {
#   background-color: #67001f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_e81ed_row1_col1, #T_e81ed_row2_col1 {
#   background-color: #a70548;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_e81ed_row3_col1 {
#   background-color: #e060ad;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_e81ed_row4_col1, #T_e81ed_row5_col1 {
#   background-color: #e3d9eb;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_e81ed_row6_col1 {
#   background-color: #f7f4f9;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_e81ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e81ed_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e81ed_level0_col1" class="col_heading level0 col1" >f1-score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e81ed_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e81ed_row0_col0" class="data row0 col0" >K-Nearest Neighbour</td>
#       <td id="T_e81ed_row0_col1" class="data row0 col1" >95.522388</td>
#     </tr>
#     <tr>
#       <th id="T_e81ed_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_e81ed_row1_col0" class="data row1 col0" >Random Forest</td>
#       <td id="T_e81ed_row1_col1" class="data row1 col1" >90.291262</td>
#     </tr>
#     <tr>
#       <th id="T_e81ed_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_e81ed_row2_col0" class="data row2 col0" >Gradient Boosting</td>
#       <td id="T_e81ed_row2_col1" class="data row2 col1" >90.291262</td>
#     </tr>
#     <tr>
#       <th id="T_e81ed_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_e81ed_row3_col0" class="data row3 col0" >Decision Tree</td>
#       <td id="T_e81ed_row3_col1" class="data row3 col1" >79.620853</td>
#     </tr>
#     <tr>
#       <th id="T_e81ed_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_e81ed_row4_col0" class="data row4 col0" >Support Vector Machine</td>
#       <td id="T_e81ed_row4_col1" class="data row4 col1" >67.980296</td>
#     </tr>
#     <tr>
#       <th id="T_e81ed_level0_row5" class="row_heading level0 row5" >0</th>
#       <td id="T_e81ed_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_e81ed_row5_col1" class="data row5 col1" >67.924528</td>
#     </tr>
#     <tr>
#       <th id="T_e81ed_level0_row6" class="row_heading level0 row6" >3</th>
#       <td id="T_e81ed_row6_col0" class="data row6 col0" >Gaussian Naive Bayes</td>
#       <td id="T_e81ed_row6_col1" class="data row6 col1" >63.054187</td>
#     </tr>
#   </tbody>
# </table>
